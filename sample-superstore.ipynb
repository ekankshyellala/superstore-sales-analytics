# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("sample_-_superstore.csv")
df
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           1  US-2023-103800  01/03/2023  01/07/2023  Standard Class
# 1           2  US-2023-112326  01/04/2023  01/08/2023  Standard Class
# 2           3  US-2023-112326  01/04/2023  01/08/2023  Standard Class
# 3           4  US-2023-112326  01/04/2023  01/08/2023  Standard Class
# 4           5  US-2023-141817  01/05/2023  01/12/2023  Standard Class
# ...       ...             ...         ...         ...             ...
# 10189   10190  US-2026-143259  12/30/2026  01/03/2027  Standard Class
# 10190   10191  US-2026-115427  12/30/2026  01/03/2027  Standard Class
# 10191   10192  US-2026-156720  12/30/2026  01/03/2027  Standard Class
# 10192   10193  US-2026-143259  12/30/2026  01/03/2027  Standard Class
# 10193   10194  CA-2026-143500  12/30/2026  01/03/2027  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800  01/03/2023  01/07/2023  Standard Class    DP-13000
# 1       2  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 2       3  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 3       4  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 4       5  US-2023-141817  01/05/2023  01/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"],errors = "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
# ...

# %%
df.drop_duplicates(subset = "Order ID",inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5111 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          5111 non-null   int64
#  1   Order ID        5111 non-null   object
#  2   Order Date      5111 non-null   datetime64[ns]
#  3   Ship Date       5111 non-null   object
#  4   Ship Mode       5111 non-null   object
#  5   Customer ID     5111 non-null   object
#  6   Customer Name   5111 non-null   object
#  7   Segment         5111 non-null   object
#  8   Country/Region  5111 non-null   object
#  9   City            5111 non-null   object
#  10  State/Province  5111 non-null   object
#  11  Postal Code     5111 non-null   int64
#  12  Region          5111 non-null   object
#  13  Product ID      5111 non-null   object
#  14  Category        5111 non-null   object
#  15  Sub-Category    5111 non-null   object
#  16  Product Name    5111 non-null   object
# ...

# %%
df.head(4)
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03  01/07/2023  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04  01/08/2023  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05  01/12/2023  Standard Class    MB-18085
# 5       6  US-2023-167199 2023-01-06  01/10/2023  Standard Class    ME-17320
#
#    Customer Name      Segment Country/Region          City  ...  \
# 0  Darren Powers     Consumer  United States       Houston  ...
# 1  Phillina Ober  Home Office  United States    Naperville  ...
# 4     Mick Brown     Consumer  United States  Philadelphia  ...
# 5  Maria Etezadi  Home Office  United States     Henderson  ...
#
#            Postal Code   Region       Product ID         Category  \
# 0 -9223372036854775808  Central  OFF-PA-10000174  Office Supplies
# 1 -9223372036854775808  Central  OFF-BI-10004094  Office Supplies
# ...

# %%
df["Postal Code"].unique()
# Out:
# array(['77095', '60540', '19143', '42420', '30605', '90049', '77340',
#        '78041', '22153', '19901', '94109', '29464', '43055', '71111',
#        '19140', '30076', '19134', '97477', '85254', '72401', '48185',
#        '37167', '33180', 'M7A', '47905', '89115', '57701', '22304',
#        '92037', '10024', '48234', '92691', '54302', '33710', '98105',
#        '92025', '92024', '60441', '23320', '7036', '89031', '65203',
#        '94521', '98103', '75220', '60653', '79424', '76017', '47374',
#        '60098', '92553', '79907', '97504', '43229', '60126', '98115',
#        '77036', '10035', '10009', '19120', '28403', '33063', '29203',
#        '10701', '98198', '80219', '48073', '40475', '95661', 'T2C',
#        '92646', '84321', '32216', '33614', '27604', '55044', '39212',
#        '75217', '94110', '91505', '33801', '37918', '45011', '28806',
#        '85705', '46368', '27405', '33445', '90036', '93727', '94122',
# ...

# %%
df.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03  01/07/2023  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04  01/08/2023  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04  01/08/2023  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States     Houston  ...       77095
# 1  Phillina Ober  Home Office  United States  Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States  Naperville  ...       60540
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
df.drop(columns = "Product Name")
# Out:
#        Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03  01/07/2023  Standard Class
# 1           2  US-2023-112326 2023-01-04  01/08/2023  Standard Class
# 2           3  US-2023-112326 2023-01-04  01/08/2023  Standard Class
# 3           4  US-2023-112326 2023-01-04  01/08/2023  Standard Class
# 4           5  US-2023-141817 2023-01-05  01/12/2023  Standard Class
# ...       ...             ...        ...         ...             ...
# 10189   10190  US-2026-143259 2026-12-30  01/03/2027  Standard Class
# 10190   10191  US-2026-115427 2026-12-30  01/03/2027  Standard Class
# 10191   10192  US-2026-156720 2026-12-30  01/03/2027  Standard Class
# 10192   10193  US-2026-143259 2026-12-30  01/03/2027  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30  01/03/2027  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"],errors = "coerce")

# %%
df.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03  01/07/2023  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04  01/08/2023  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04  01/08/2023  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States     Houston  ...       77095
# 1  Phillina Ober  Home Office  United States  Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States  Naperville  ...       60540
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
df["Ship Date"] = pd.to_datetime(df["Ship Date"],errors = "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
df["Shipping Days"] = (df["Ship Date"]-df["Order Date"]).dt.days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
df.drop(columns = "Product Name")
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05 2023-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ...   Region  \
# 0  Darren Powers     Consumer  United States       Houston  ...  Central
# 1  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 2  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 3  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 4     Mick Brown     Consumer  United States  Philadelphia  ...     East
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df["Country/Region"].unique()
# Out:
# array(['United States', 'Canada'], dtype=object)

# %%
df.groupby("Country/Region")["Sales"].mean()
# Out:
# Country/Region
# Canada           146.667470
# United States    229.858001
# Name: Sales, dtype: float64

# %%
df.groupby("Country/Region")["Profit"].mean()
# Out:
# Country/Region
# Canada           29.498965
# United States    28.656896
# Name: Profit, dtype: float64

# %%
df.groupby("Segment")["Sales"].mean()
# Out:
# Segment
# Consumer       221.673885
# Corporate      231.652471
# Home Office    241.397933
# Name: Sales, dtype: float64

# %%
df.groupby("Segment")["Profit"].mean()
# Out:
# Segment
# Consumer       25.823035
# Corporate      30.501502
# Home Office    33.831996
# Name: Profit, dtype: float64

# %%
df.groupby("Country/Region")["Order ID"].value_counts()
# Out:
# Country/Region  Order ID
# Canada          CA-2023-131807    6
#                 CA-2026-131807    6
#                 CA-2023-115238    5
#                 CA-2023-151799    5
#                 CA-2024-115238    5
#                                  ..
# United States   US-2026-169607    1
#                 US-2026-169810    1
#                 US-2026-169817    1
#                 US-2026-169901    1
#                 US-2026-169929    1
# Name: count, Length: 5111, dtype: int64

# %%
df.groupby("City")["Profit"].mean()
# Out:
# City
# Aberdeen         6.630000
# Abilene         -3.758400
# Akron           -8.887410
# Albuquerque     45.292007
# Alexandria      19.913644
#                   ...
# Woonsocket      19.669775
# Yonkers        184.517047
# York           -20.433840
# Yucaipa         13.208000
# Yuma          -116.497725
# Name: Profit, Length: 542, dtype: float64

# %%
round(df.groupby("Ship Mode")["Profit"].mean(),2)
# Out:
# Ship Mode
# First Class       31.66
# Same Day          29.54
# Second Class      29.79
# Standard Class    27.48
# Name: Profit, dtype: float64

# %%
df.groupby("Category")["Sales"].mean()
# Out:
# Category
# Furniture          342.911295
# Office Supplies    119.434288
# Technology         450.344922
# Name: Sales, dtype: float64

# %%
df.to_csv(r"C:\Users\EKANKSH\OneDrive\Documents\cleanedsuperstore.csv",index = False )
